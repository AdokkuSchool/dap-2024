# %% [markdown]
# <a href="https://colab.research.google.com/github/AdokkuSchool/dap-2024/blob/main/les01/rep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа №1
#
# ## Цель работы
# Ознакомиться с GitHub и Google Colab, научиться создавать репозитории и pull request.
#
# ## Ход работы
# 1. Создан аккаунт GitHub
# 2. Выполнен fork репозитория dap-2024
# 3. Создан аккаунт Google Colab
# 4. Настроена интеграция Google Colab и GitHub
# 5. Создан отчет в формате Jupyter Notebook
#
# ## Используемые ресурсы
# - [GitHub](https://github.com)
# - [Google Colab](https://colab.research.google.com)
#
# ## Вывод
# В ходе лабораторной работы были освоены базовые навыки работы с GitHub и Google Colab.
